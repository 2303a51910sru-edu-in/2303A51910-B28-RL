# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51910sru-edu-in/2303A51910-B28-RL/blob/main/RL_Ass05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)
    rewards = []

    print(f"\nRunning {env_name}")
    print("-" * 40)

    for episode in range(episodes):
        state, info = env.reset()
        done = False
        episode_reward = 0

        print(f"\nEpisode {episode+1}")
        print("Initial State:", state)

        while not done:
            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            done = terminated or truncated
            episode_reward += reward

            print(f"State: {state}")
            print(f"Action: {action}")
            print(f"Reward: {reward}")
            print(f"Next State: {next_state}")

            state = next_state

        rewards.append(episode_reward)
        print("Episode Reward:", episode_reward)

    env.close()

    total_reward = sum(rewards)
    average_reward = total_reward / episodes

    print("\nFinal Results")
    print("Environment :", env_name)
    print("Total Reward:", total_reward)
    print("Average Reward:", average_reward)

random_agent("CartPole-v1")
random_agent("MountainCar-v0")
random_agent("FrozenLake-v1")
# Out:
# Running CartPole-v1
# ----------------------------------------
#
# Episode 1
# Initial State: [-0.03487586 -0.000431   -0.02343209  0.04652741]
# State: [-0.03487586 -0.000431   -0.02343209  0.04652741]
# Action: 1
# Reward: 1.0
# Next State: [-0.03488448  0.19501898 -0.02250155 -0.2534555 ]
# State: [-0.03488448  0.19501898 -0.02250155 -0.2534555 ]
# Action: 1
# Reward: 1.0
# Next State: [-0.0309841   0.3904549  -0.02757066 -0.55315   ]
# State: [-0.0309841   0.3904549  -0.02757066 -0.55315   ]
# Action: 0
# Reward: 1.0
# Next State: [-0.023175    0.19573073 -0.03863366 -0.26927954]
# State: [-0.023175    0.19573073 -0.03863366 -0.26927954]
# Action: 0
# Reward: 1.0
# Next State: [-0.01926039  0.00118079 -0.04401925  0.01097213]
# State: [-0.01926039  0.00118079 -0.04401925  0.01097213]
# Action: 1
# Reward: 1.0
# Next State: [-0.01923677  0.1969055  -0.04379981 -0.295268  ]
# State: [-0.01923677  0.1969055  -0.04379981 -0.295268  ]
# Action: 1
# Reward: 1.0
# ...
